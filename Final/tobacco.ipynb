# %%
#Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import plotly
import plotly.plotly as py
import plotly.tools as tls
import plotly.graph_objs as go
import time 
import  pandas_datareader as web
# Package and modules for importing data;
import datetime
import requests
import json as js
import csv
import seaborn as sns
plotly.tools.set_credentials_file(username='Roshan92', api_key='rwuf1Ip4A0xGTRAaBSlt')

# %%
tobacco=pd.read_csv('tobacco.csv')

# %%
import cufflinks as cf
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
tobacco1 = tobacco.pivot_table(index="Year", values=["Smokeeveryday","Smokesomedays","Formersmoker","Neversmoked"])

# %%
tobacco1
# Out:
#       Formersmoker  Neversmoked  Smokeeveryday  Smokesomedays
# Year
# 1995     25.316667    52.018750      20.008333       2.664583
# 1996     24.027083    51.975000      19.854167       4.158333
# 1997     23.922000    52.738000      19.086000       4.248000
# 1998     24.116327    52.669388      18.663265       4.551020
# 1999     24.066667    52.725000      18.350000       4.841667
# 2000     24.695918    52.502041      17.738776       5.067347
# 2001     24.900000    51.731915      17.614894       5.748936
# 2002     24.853191    51.923404      18.197872       5.023404
# 2003     24.993878    52.430612      17.400000       5.173469
# 2004     23.769565    54.684783      16.004348       5.558696
# 2005     24.797959    54.151020      15.622449       5.436735
# 2006     24.820408    54.904082      15.093878       5.173469
# 2007     24.790000    55.230000      14.852000       5.124000
# 2008     25.134000    55.910000      13.956000       5.008000
# ...

# %%
tobacco1.iplot()
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~Roshan92/0 or inside your plot.ly account where it is named 'Plotly Playground 2017-12-09 11:26:25'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Roshan92/0.embed" height="525px" width="100%"></iframe>

# %%
states=tobacco.loc[(tobacco['State']=='Neveda') | (tobacco['State']=='Arkansas') | (tobacco['State']=='Arizona') | (tobacco['State']=='Illinois') | (tobacco['State']=='Pennsylvania') | (tobacco['State']=='West Virginia') | (tobacco['State']=='New York') | (tobacco['State']=='North Carolina') | (tobacco['State']=='South Carolina')]
states
# Out:
#               State  Year  Smokeeveryday  Smokesomedays  Formersmoker  \
# 7    North Carolina  2000           20.7            5.4          24.3
# 16   North Carolina  1996           21.9            3.8          23.1
# 24         Arkansas  1998           22.2            3.7          24.2
# 36         Arkansas  2001           20.1            5.4          23.6
# 39          Arizona  2002           17.8            5.6          24.4
# 42         Illinois  2001           17.4            6.3          23.7
# 45         Arkansas  2010           17.3            5.6          24.1
# 46     Pennsylvania  1997           20.0            4.2          22.7
# 47          Arizona  2004           13.5            5.1          24.5
# 53         New York  2001           16.6            6.6          23.8
# 58    West Virginia  2007           21.7            5.2          24.5
# 63         New York  2007           12.8            6.1          25.5
# ...

# %%
smoking = states.pivot_table(index="State", values=["Smokeeveryday"])
smoking
# Out:
#                 Smokeeveryday
# State
# Arizona             15.237500
# Arkansas            19.975000
# Illinois            15.957143
# New York            15.313333
# North Carolina      19.020000
# Pennsylvania        17.975000
# South Carolina      18.093750
# West Virginia       22.831250

# %%
smoking.iplot(kind='barh')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~Roshan92/2.embed" height="525px" width="100%"></iframe>
